# %% [markdown]
# # Mergers & Acquisitions - Great data to allow us to remove this "Noise" and use Capital Allocation much more efficiently!
#
# Just like we used https://stockanalysis.com under 08_renamings.ipynb , we can use the same website to get ALL historic Mergers and Acquisitions and make sure they our algos avoid these, and don't waste allocation on these!
#
# ### 🔀 Where the Data Comes From: `stockanalysis.com` (Cheap/free Solution = free trial or $10 one-off, and for ongoing updates the site gives last 12 months ticker changes for FREE under the public "Recent Mergers and Acquisitions" public endpoint with no login required!)
# https://stockanalysis.com/actions/acquisitions/
