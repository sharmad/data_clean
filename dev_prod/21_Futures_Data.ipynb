# %% [markdown]
# # Databento = FREE

# %% [markdown]
# ## ChatGPT:
# To pull this off for under $100 today, you only have two viable paths.
#
# #### 1. Databento (The Best Route for 1-Min Data)
# I need to correct my previous statement: Databento’s CME Globex historical data (which includes CME, CBOT, NYMEX, and COMEX) actually **goes back to June 6, 2010**. They also now cover ICE Futures US and ICE Europe. This covers practically all 40 of the most liquid global futures.
#
# Because Databento bills strictly by the byte, and you only want `ohlcv-1m` (1-minute OHLCV) data, the file sizes are tiny.
# * A decade of 1-minute data for a single symbol is only a few megabytes.
# * Pulling 16 years of 1-minute data for 40 symbols will likely cost you **less than $20 to $30 total**.
# * **The ultimate budget hack:** Databento gives new users a **$125 free credit** upon signing up. If you use their Python API to request the 1-minute continuous contracts, you can likely pull your entire 40-market dataset back to 2010 without actually spending a single dollar of your own money.

# %% [markdown]
# ## Claude:
# If your **only requirement** is:
#
# > **Continuous futures, 1-minute bars, 2010+ history, ~40 liquid futures, under $100 total**
#
# then the answer is much simpler.
#
# ## Best Option: Databento
#
# Databento now provides native continuous futures symbology and minute bars across CME and ICE markets, with CME history back to June 2010 and usage-based pricing. ([Databento][1])
#
# ### Why it wins
#
# * Native continuous contracts
# * Native 1-minute OHLCV bars
# * CME, CBOT, NYMEX, COMEX
# * ICE Futures US
# * ICE Europe
# * Eurex
# * Usage-based pricing
# * $125 signup credit available to new accounts ([Databento][1])
#
# For your use case, it is probably the only institutional-grade solution that realistically stays below $100.
#
# ### Expected cost
#
# For:
#
# * ES
# * NQ
# * RTY
# * YM
# * ZN
# * ZB
# * CL
# * NG
# * RB
# * HO
# * GC
# * SI
# * HG
# * 6E
# * 6J
# * 6B
# * Corn
# * Soybeans
# * Wheat
# * Coffee
# * Sugar
# * Cocoa
# * Cotton
#
# and similar contracts back to 2010,
#
# I would expect somewhere between **$10–50 total**, not monthly, assuming you're only downloading minute OHLCV. Databento charges by downloaded data volume and minute bars are extremely compact. ([Databento][2])
#
# ---
#
# ## Second Best: IQFeed
#
# [IQFeed](https://www.iqfeed.net?utm_source=chatgpt.com)
#
# Pros:
#
# * Excellent reputation among retail quants
# * Long futures history
# * Continuous futures symbols
# * Stable API
#
# Cons:
#
# * Recurring monthly cost
# * Exchange fees
# * More expensive than Databento for a one-time historical download
#
# Community discussions frequently cite IQFeed as one of the few practical retail sources for extensive historical futures minute data. ([Reddit][3])
#
# ### Cost
#
# Typically:
#
# * IQFeed subscription
# * Exchange fees
#
# Expect roughly $100+/month once everything is included.
#
# For a one-time historical download, Databento is usually cheaper.
#
# ---
#
# ## Third Best: Norgate Data
#
# [Norgate Data](https://norgatedata.com?utm_source=chatgpt.com)
#
# Pros:
#
# * Arguably the cleanest continuous futures series available
# * Professional roll logic
# * Built specifically for systematic futures research
#
# Cons:
#
# * Mostly daily and end-of-day focused
# * Not cheap
# * Not ideal if you specifically need minute bars
#
# Great for trend-following research, not my first choice for intraday futures.
#
# ---
#
# ## What I would avoid
#
# ### Interactive Brokers
#
# * History limits
# * Continuous contracts are limited
# * Painful for large-scale research
#
# ### TradeStation scraping
#
# It works, but:
#
# * Fragile
# * Time-consuming
# * Exchange subscription hassle
# * Data extraction effort
#
# Only worth it if you already have a funded TradeStation account.
#
# ---
#
# ## My quant ranking for your exact use case
#
# | Provider     | Continuous Futures | 1-Minute         | 2010+   | Cost              |
# | ------------ | ------------------ | ---------------- | ------- | ----------------- |
# | Databento    | Yes                | Yes              | Yes     | $10–50 total      |
# | IQFeed       | Yes                | Yes              | Yes     | ~$100+/month      |
# | Norgate      | Yes                | Mostly EOD focus | Yes     | Higher            |
# | TradeStation | Yes                | Yes              | Yes     | Manual extraction |
# | IBKR         | Weak               | Partial          | Limited | Not recommended   |
#
# ### Conclusion
#
# For **continuous futures only**, with **2010-present 1-minute history**, and a budget under $100:
#
# 1. **Databento** is the clear winner.
# 2. **IQFeed** is the best recurring subscription if you need ongoing updates.
# 3. **Everything else is either more expensive or more work.**
#
# The only caveat is that many experienced futures researchers still prefer to build their own continuous contracts because vendor roll logic can differ. Several recent discussions specifically mention shortcomings in pre-built continuous series near rollover periods. ([Reddit][4])
#
# If you're willing to accept vendor-defined continuous contracts, Databento is currently the cheapest high-quality solution I know of.
#
# [1]: https://databento.com/futures?utm_source=chatgpt.com "Futures Market Data - Live and historical futures data API"
# [2]: https://databento.com/pricing/?utm_source=chatgpt.com "Databento"
# [3]: https://www.reddit.com/r/algotrading/comments/emmik2?utm_source=chatgpt.com "Data subscriptions for historical data for futures with 1 min (or smaller) scale"
# [4]: https://www.reddit.com/r/Databento/comments/1qlil4e/best_utilization_of_continuous_contracts_for_cme/?utm_source=chatgpt.com "Best utilization of continuous contracts for CME futures"
