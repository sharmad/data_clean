# %% [markdown]
# TipRanks? NO!
#
# I think for us Benzinga Analyst upgrades are more than enough. Cos for a stock with EP price action, even an average-rated Analyst upgrade is more than enough conviction + hype.
#
# TipRanks are more for investors.
